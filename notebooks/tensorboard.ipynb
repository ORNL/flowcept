# %%
# Sleeps are used because these notebooks are being tested automatically as part of the CI/CD. 
# In a normal user interaction, these sleeps would not be necessary.
from time import sleep

import os
import shutil
from uuid import uuid4
from time import sleep

# %%
def run_tensorboard_hparam_tuning(tensorboard_events_dir, epochs=2):
    # Code based on: https://www.tensorflow.org/tensorboard/hyperparameter_tuning_with_hparams
    wf_id = str(uuid4())
    import tensorflow as tf
    from tensorboard.plugins.hparams import api as hp

    fashion_mnist = tf.keras.datasets.fashion_mnist

    (x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
    x_train, x_test = x_train / 255.0, x_test / 255.0

    HP_NUM_UNITS = hp.HParam("num_units", hp.Discrete([16, 32]))
    HP_DROPOUT = hp.HParam("dropout", hp.RealInterval(0.1, 0.2))
    HP_OPTIMIZER = hp.HParam("optimizer", hp.Discrete(["adam", "sgd"]))
    HP_BATCHSIZES = hp.HParam("batch_size", hp.Discrete([32, 64]))

    HP_MODEL_CONFIG = hp.HParam("model_config")
    HP_OPTIMIZER_CONFIG = hp.HParam("optimizer_config")

    METRIC_ACCURACY = "accuracy"

    with tf.summary.create_file_writer(tensorboard_events_dir).as_default():
        hp.hparams_config(
            hparams=[
                HP_NUM_UNITS,
                HP_DROPOUT,
                HP_OPTIMIZER,
                HP_BATCHSIZES,
                HP_MODEL_CONFIG,
                HP_OPTIMIZER_CONFIG,
            ],
            metrics=[hp.Metric(METRIC_ACCURACY, display_name="Accuracy")],
        )

    def train_test_model(hparams, tensorboard_events_dir):
        model = tf.keras.models.Sequential(
            [
                tf.keras.layers.Flatten(),
                tf.keras.layers.Dense(
                    hparams[HP_NUM_UNITS], activation=tf.nn.relu
                ),
                tf.keras.layers.Dropout(hparams[HP_DROPOUT]),
                tf.keras.layers.Dense(10, activation=tf.nn.softmax),
            ]
        )
        model.compile(
            optimizer=hparams[HP_OPTIMIZER],
            loss="sparse_categorical_crossentropy",
            metrics=["accuracy"],
        )

        model.fit(
            x_train,
            y_train,
            epochs=epochs,
            callbacks=[
                tf.keras.callbacks.TensorBoard(tensorboard_events_dir),
                # log metrics
                hp.KerasCallback(tensorboard_events_dir, hparams),  # log hparams
            ],
            batch_size=hparams[HP_BATCHSIZES],
        )  # Run with 1 epoch to speed things up for tests
        _, accuracy = model.evaluate(x_test, y_test)
        return accuracy

    def run(run_dir, hparams):
        with tf.summary.create_file_writer(run_dir).as_default():
            hp.hparams(hparams)  # record the values used in this trial
            accuracy = train_test_model(hparams, tensorboard_events_dir)
            tf.summary.scalar(METRIC_ACCURACY, accuracy, step=1)

    session_num = 0

    for num_units in HP_NUM_UNITS.domain.values:
        for dropout_rate in (
            HP_DROPOUT.domain.min_value,
            HP_DROPOUT.domain.max_value,
        ):
            for optimizer in HP_OPTIMIZER.domain.values:
                for batch_size in HP_BATCHSIZES.domain.values:
                    # These two added ids below are optional and useful
                    # just to contextualize this run.
                    hparams = {
                        "workflow_id": wf_id,
                        "activity_id": "hyperparam_evaluation",
                        "epochs": epochs,
                        HP_NUM_UNITS: num_units,
                        HP_DROPOUT: dropout_rate,
                        HP_OPTIMIZER: optimizer,
                        HP_BATCHSIZES: batch_size,
                    }
                    run_name = f"wf_id_{wf_id}_{session_num}"
                    print("--- Starting trial: %s" % run_name)
                    print(f"{hparams}")
                    run(f"{tensorboard_events_dir}/" + run_name, hparams)
                    session_num += 1

    return wf_id

# %%
# Set log levels
os.environ['LOG_STREAM_LEVEL'] = "error"
os.environ['LOG_FILE_LEVEL'] = "debug"

# %% [markdown]
# ## Set up tensorboard events directory

# %%
# Optional: Delete old tensorboard directories
for file in os.listdir("."):
    if file.startswith("tb_"):
        shutil.rmtree(file)

# %%
tensorboard_events_dir = f"tb_{uuid4()}"
print(f"Creating new directory: {tensorboard_events_dir} ...")
os.mkdir(tensorboard_events_dir)
sleep(5)
print(f"Created.")
# Out:
# Creating new directory: tb_fc667c6d-d92a-48ec-afa4-2faf8c19b695 ...
# Created.

# %% [markdown]
# ## Get training parameters from previous Dask workflow run

# %%
from flowcept import TaskQueryAPI
from flowcept.commons.utils import get_utc_minutes_ago
query_api = TaskQueryAPI()

# %%
_filter = {
    "utc_timestamp": { "$gte" : get_utc_minutes_ago(60) },
    "campaign_id": "super_campaign",
    "generated.epochs": { "$gte" : 0 }
}
docs = query_api.query(filter=_filter)
epochs_params = set()
for doc in docs:
    print(f"task={doc['task_id']}, generated epochs={doc['generated']['epochs']}")
    epochs_params.add(doc['generated']['epochs'])
epochs_params
# Out:
# task=calculate_batch_and_epochs-bf4ebf3fbbc76e7517ea3b4eab46c56e, generated epochs=2
# task=calculate_batch_and_epochs-5af210f426b0a8c42a9302411639c68e, generated epochs=2
# task=calculate_batch_and_epochs-2153e7442c9cb4ec0537bd7f6504f448, generated epochs=2
# task=calculate_batch_and_epochs-4acef3484d0b37571f7656a9d5efd819, generated epochs=2
# task=calculate_batch_and_epochs-cea197d7e360873a91a6bf0e015023a1, generated epochs=2
# task=calculate_batch_and_epochs-fba26a979e3a9ad1d59824712b3b3e32, generated epochs=2
# task=calculate_batch_and_epochs-6b979ef78f9983cedd596e25a1ac8746, generated epochs=2
# {2}

# %% [markdown]
# ## Initialize Tensorboard's interceptor

# %%
from flowcept import TensorboardInterceptor
interceptor = TensorboardInterceptor()
interceptor.settings.file_path = tensorboard_events_dir

# %% [markdown]
# ## Initialize consumer API

# %%
from flowcept import FlowceptConsumerAPI
consumer = FlowceptConsumerAPI(interceptor)
consumer.start()

# %% [markdown]
# ## Start training

# %%
for epochs in epochs_params:
    workflow_id = run_tensorboard_hparam_tuning(tensorboard_events_dir)
    print(f"{epochs}, {workflow_id}")
# Out:
# --- Starting trial: wf_id_46010403-1191-4136-b072-ff84f6683856_0
# {'workflow_id': '46010403-1191-4136-b072-ff84f6683856', 'activity_id': 'hyperparam_evaluation', 'epochs': 2, HParam(name='num_units', domain=Discrete([16, 32]), display_name=None, description=None): 16, HParam(name='dropout', domain=RealInterval(0.1, 0.2), display_name=None, description=None): 0.1, HParam(name='optimizer', domain=Discrete(['adam', 'sgd']), display_name=None, description=None): 'adam', HParam(name='batch_size', domain=Discrete([32, 64]), display_name=None, description=None): 32}
# Epoch 1/2
# 2023-06-27 12:29:24.897901: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 1875/1875 [==============================] - 1s 408us/step - loss: 0.6734 - accuracy: 0.7617
# Epoch 2/2
# 1875/1875 [==============================] - 1s 388us/step - loss: 0.4859 - accuracy: 0.8269
# 313/313 [==============================] - 0s 356us/step - loss: 0.4450 - accuracy: 0.8390
# --- Starting trial: wf_id_46010403-1191-4136-b072-ff84f6683856_1
# {'workflow_id': '46010403-1191-4136-b072-ff84f6683856', 'activity_id': 'hyperparam_evaluation', 'epochs': 2, HParam(name='num_units', domain=Discrete([16, 32]), display_name=None, description=None): 16, HParam(name='dropout', domain=RealInterval(0.1, 0.2), display_name=None, description=None): 0.1, HParam(name='optimizer', domain=Discrete(['adam', 'sgd']), display_name=None, description=None): 'adam', HParam(name='batch_size', domain=Discrete([32, 64]), display_name=None, description=None): 64}
# Epoch 1/2
# 938/938 [==============================] - 1s 529us/step - loss: 0.7536 - accuracy: 0.7469
# Epoch 2/2
# 938/938 [==============================] - 1s 592us/step - loss: 0.5237 - accuracy: 0.8179
# 313/313 [==============================] - 0s 355us/step - loss: 0.4676 - accuracy: 0.8357
# --- Starting trial: wf_id_46010403-1191-4136-b072-ff84f6683856_2
# {'workflow_id': '46010403-1191-4136-b072-ff84f6683856', 'activity_id': 'hyperparam_evaluation', 'epochs': 2, HParam(name='num_units', domain=Discrete([16, 32]), display_name=None, description=None): 16, HParam(name='dropout', domain=RealInterval(0.1, 0.2), display_name=None, description=None): 0.1, HParam(name='optimizer', domain=Discrete(['adam', 'sgd']), display_name=None, description=None): 'sgd', HParam(name='batch_size', domain=Discrete([32, 64]), display_name=None, description=None): 32}
# Epoch 1/2
# 1875/1875 [==============================] - 1s 369us/step - loss: 0.9852 - accuracy: 0.6564
# Epoch 2/2
# 1875/1875 [==============================] - 1s 386us/step - loss: 0.6574 - accuracy: 0.7710
# 313/313 [==============================] - 0s 358us/step - loss: 0.5690 - accuracy: 0.8026
# --- Starting trial: wf_id_46010403-1191-4136-b072-ff84f6683856
# {'workflow_id': '46010403-1191-4136-b072-ff84f6683856', 'activity_id': 'hyperparam_evaluation', 'epochs': 2, HParam(name='num_units', domain=Discrete([16, 32]), display_name=None, description=None): 32, HParam(name='dropout', domain=RealInterval(0.1, 0.2), display_name=None, description=None): 0.2, HParam(name='optimizer', domain=Discrete(['adam', 'sgd']), display_name=None, description=None): 'sgd', HParam(name='batch_size', domain=Discrete([32, 64]), display_name=None, description=None): 32}
# Epoch 1/2
# 1875/1875 [==============================] - 1s 460us/step - loss: 0.9964 - accuracy: 0.6525
# Epoch 2/2
# 1875/1875 [==============================] - 1s 463us/step - loss: 0.6737 - accuracy: 0.7666
# 313/313 [==============================] - 0s 378us/step - loss: 0.5610 - accuracy: 0.8011
# --- Starting trial: wf_id_46010403-1191-4136-b072-ff84f6683856_15
# {'workflow_id': '46010403-1191-4136-b072-ff84f6683856', 'activity_id': 'hyperparam_evaluation', 'epochs': 2, HParam(name='num_units', domain=Discrete([16, 32]), display_name=None, description=None): 32, HParam(name='dropout', domain=RealInterval(0.1, 0.2), display_name=None, description=None): 0.2, HParam(name='optimizer', domain=Discrete(['adam', 'sgd']), display_name=None, description=None): 'sgd', HParam(name='batch_size', domain=Discrete([32, 64]), display_name=None, description=None): 64}
# Epoch 1/2
# 938/938 [==============================] - 1s 498us/step - loss: 1.1922 - accuracy: 0.5917
# Epoch 2/2
# 938/938 [==============================] - 0s 498us/step - loss: 0.7655 - accuracy: 0.7410
# 313/313 [==============================] - 0s 365us/step - loss: 0.6348 - accuracy: 0.7873
# 2, 46010403-1191-4136-b072-ff84f6683856

# %%
sleep(10)
consumer.stop()

# %% [markdown]
# ## Get the training metadata stored from this workflow

# %%
_filter = {
    "workflow_id": workflow_id
}
docs = query_api.query(filter=_filter)
docs
# Out:
# [{'task_id': 'events.out.tfevents.1687883364.MAC132633.54853.1.v2',
#   'workflow_id': '46010403-1191-4136-b072-ff84f6683856',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 32.0,
#    'dropout': 0.1,
#    'epochs': 2.0,
#    'num_units': 16.0,
#    'optimizer': 'adam'},
#   'generated': {'accuracy': 0.8389999866485596},
#   'utc_timestamp': 1687897769.883982,
#   'custom_metadata': {'event_file': 'wf_id_46010403-1191-4136-b072-ff84f6683856_0',
#    'log_path': 'tb_fc667c6d-d92a-48ec-afa4-2faf8c19b695/wf_id_46010403-1191-4136-b072-ff84f6683856_0'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'campaign_id': 'super_campaign',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'login_name',
#   'hostname': 'mac132633.ornl.gov',
#   'extra_metadata': {'place_holder': ''},
#   'debug': True,
#   'finished': True},
#  {'task_id': 'events.out.tfevents.1687883367.MAC132633.54853.4.v2',
#   'workflow_id': '46010403-1191-4136-b072-ff84f6683856',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 64.0,
#    'dropout': 0.1,
#    'epochs': 2.0,
#    'num_units': 16.0,
#    'optimizer': 'adam'},
#   'generated': {'accuracy': 0.8356999754905701},
#   'utc_timestamp': 1687897769.895614,
#   'custom_metadata': {'event_file': 'wf_id_46010403-1191-4136-b072-ff84f6683856_1',
#    'log_path': 'tb_fc667c6d-d92a-48ec-afa4-2faf8c19b695/wf_id_46010403-1191-4136-b072-ff84f6683856_1'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'campaign_id': 'super_campaign',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'login_name',
#   'hostname': 'mac132633.ornl.gov',
#   'extra_metadata': {'place_holder': ''},
#   'debug': True,
#   'finished': True},
#  {'task_id': 'events.out.tfevents.1687883368.MAC132633.54853.7.v2',
#   'workflow_id': '46010403-1191-4136-b072-ff84f6683856',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 32.0,
#    'dropout': 0.1,
#    'epochs': 2.0,
#    'num_units': 16.0,
#    'optimizer': 'sgd'},
#   'generated': {'accuracy': 0.8026000261306763},
#   'utc_timestamp': 1687897774.97616,
#   'custom_metadata': {'event_file': 'wf_id_46010403-1191-4136-b072-ff84f6683856_2',
#    'log_path': 'tb_fc667c6d-d92a-48ec-afa4-2faf8c19b695/wf_id_46010403-1191-4136-b072-ff84f6683856_2'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'campaign_id': 'super_campaign',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'login_name',
#   'hostname': 'mac132633.ornl.gov',
#   'extra_metadata': {'place_holder': ''},
#   'debug': True,
#   'finished': True},
#  {'task_id': 'events.out.tfevents.1687883370.MAC132633.54853.10.v2',
#   'workflow_id': '46010403-1191-4136-b072-ff84f6683856',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 64.0,
#    'dropout': 0.1,
#    'epochs': 2.0,
#    'num_units': 16.0,
#    'optimizer': 'sgd'},
#   'generated': {'accuracy': 0.7815999984741211},
#   'utc_timestamp': 1687897774.980992,
#   'custom_metadata': {'event_file': 'wf_id_46010403-1191-4136-b072-ff84f6683856_3',
#    'log_path': 'tb_fc667c6d-d92a-48ec-afa4-2faf8c19b695/wf_id_46010403-1191-4136-b072-ff84f6683856_3'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'campaign_id': 'super_campaign',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'login_name',
#   'hostname': 'mac132633.ornl.gov',
#   'extra_metadata': {'place_holder': ''},
#   'debug': True,
#   'finished': True},
#  {'task_id': 'events.out.tfevents.1687883371.MAC132633.54853.13.v2',
#   'workflow_id': '46010403-1191-4136-b072-ff84f6683856',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 32.0,
#    'dropout': 0.2,
#    'epochs': 2.0,
#    'num_units': 16.0,
#    'optimizer': 'adam'},
#   'generated': {'accuracy': 0.8309999704360962},
#   'utc_timestamp': 1687897774.98542,
#   'custom_metadata': {'event_file': 'wf_id_46010403-1191-4136-b072-ff84f6683856_4',
#    'log_path': 'tb_fc667c6d-d92a-48ec-afa4-2faf8c19b695/wf_id_46010403-1191-4136-b072-ff84f6683856_4'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'campaign_id': 'super_campaign',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'login_name',
#   'hostname': 'mac132633.ornl.gov',
#   'extra_metadata': {'place_holder': ''},
#   'debug': True,
#   'finished': True},
#  {'task_id': 'events.out.tfevents.1687883374.MAC132633.54853.16.v2',
#   'workflow_id': '46010403-1191-4136-b072-ff84f6683856',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 64.0,
#    'dropout': 0.2,
#    'epochs': 2.0,
#    'num_units': 16.0,
#    'optimizer': 'adam'},
#   'generated': {'accuracy': 0.8226000070571899},
#   'utc_timestamp': 1687897780.098912,
#   'custom_metadata': {'event_file': 'wf_id_46010403-1191-4136-b072-ff84f6683856_5',
#    'log_path': 'tb_fc667c6d-d92a-48ec-afa4-2faf8c19b695/wf_id_46010403-1191-4136-b072-ff84f6683856_5'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'campaign_id': 'super_campaign',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'login_name',
#   'hostname': 'mac132633.ornl.gov',
#   'extra_metadata': {'place_holder': ''},
#   'debug': True,
#   'finished': True},
#  {'task_id': 'events.out.tfevents.1687883375.MAC132633.54853.19.v2',
#   'workflow_id': '46010403-1191-4136-b072-ff84f6683856',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 32.0,
#    'dropout': 0.2,
#    'epochs': 2.0,
#    'num_units': 16.0,
#    'optimizer': 'sgd'},
#   'generated': {'accuracy': 0.7786999940872192},
#   'utc_timestamp': 1687897780.103458,
#   'custom_metadata': {'event_file': 'wf_id_46010403-1191-4136-b072-ff84f6683856_6',
#    'log_path': 'tb_fc667c6d-d92a-48ec-afa4-2faf8c19b695/wf_id_46010403-1191-4136-b072-ff84f6683856_6'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'campaign_id': 'super_campaign',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'login_name',
#   'hostname': 'mac132633.ornl.gov',
#   'extra_metadata': {'place_holder': ''},
#   'debug': True,
#   'finished': True},
#  {'task_id': 'events.out.tfevents.1687883377.MAC132633.54853.22.v2',
#   'workflow_id': '46010403-1191-4136-b072-ff84f6683856',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 64.0,
#    'dropout': 0.2,
#    'epochs': 2.0,
#    'num_units': 16.0,
#    'optimizer': 'sgd'},
#   'generated': {'accuracy': 0.774399995803833},
#   'utc_timestamp': 1687897780.108158,
#   'custom_metadata': {'event_file': 'wf_id_46010403-1191-4136-b072-ff84f6683856_7',
#    'log_path': 'tb_fc667c6d-d92a-48ec-afa4-2faf8c19b695/wf_id_46010403-1191-4136-b072-ff84f6683856_7'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'campaign_id': 'super_campaign',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'login_name',
#   'hostname': 'mac132633.ornl.gov',
#   'extra_metadata': {'place_holder': ''},
#   'debug': True,
#   'finished': True},
#  {'task_id': 'events.out.tfevents.1687883382.MAC132633.54853.31.v2',
#   'workflow_id': '46010403-1191-4136-b072-ff84f6683856',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 32.0,
#    'dropout': 0.1,
#    'epochs': 2.0,
#    'num_units': 32.0,
#    'optimizer': 'sgd'},
#   'generated': {'accuracy': 0.8192999958992004},
#   'utc_timestamp': 1687897785.405195,
#   'custom_metadata': {'event_file': 'wf_id_46010403-1191-4136-b072-ff84f6683856_10',
#    'log_path': 'tb_fc667c6d-d92a-48ec-afa4-2faf8c19b695/wf_id_46010403-1191-4136-b072-ff84f6683856_10'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'campaign_id': 'super_campaign',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'login_name',
#   'hostname': 'mac132633.ornl.gov',
#   'extra_metadata': {'place_holder': ''},
#   'debug': True,
#   'finished': True},
#  {'task_id': 'events.out.tfevents.1687883378.MAC132633.54853.25.v2',
#   'workflow_id': '46010403-1191-4136-b072-ff84f6683856',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 32.0,
#    'dropout': 0.1,
#    'epochs': 2.0,
#    'num_units': 32.0,
#    'optimizer': 'adam'},
#   'generated': {'accuracy': 0.8445000052452087},
#   'utc_timestamp': 1687897785.417959,
#   'custom_metadata': {'event_file': 'wf_id_46010403-1191-4136-b072-ff84f6683856_8',
#    'log_path': 'tb_fc667c6d-d92a-48ec-afa4-2faf8c19b695/wf_id_46010403-1191-4136-b072-ff84f6683856_8'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'campaign_id': 'super_campaign',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'login_name',
#   'hostname': 'mac132633.ornl.gov',
#   'extra_metadata': {'place_holder': ''},
#   'debug': True,
#   'finished': True},
#  {'task_id': 'events.out.tfevents.1687883381.MAC132633.54853.28.v2',
#   'workflow_id': '46010403-1191-4136-b072-ff84f6683856',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 64.0,
#    'dropout': 0.1,
#    'epochs': 2.0,
#    'num_units': 32.0,
#    'optimizer': 'adam'},
#   'generated': {'accuracy': 0.8479999899864197},
#   'utc_timestamp': 1687897785.422158,
#   'custom_metadata': {'event_file': 'wf_id_46010403-1191-4136-b072-ff84f6683856_9',
#    'log_path': 'tb_fc667c6d-d92a-48ec-afa4-2faf8c19b695/wf_id_46010403-1191-4136-b072-ff84f6683856_9'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'campaign_id': 'super_campaign',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'login_name',
#   'hostname': 'mac132633.ornl.gov',
#   'extra_metadata': {'place_holder': ''},
#   'debug': True,
#   'finished': True},
#  {'task_id': 'events.out.tfevents.1687883384.MAC132633.54853.34.v2',
#   'workflow_id': '46010403-1191-4136-b072-ff84f6683856',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 64.0,
#    'dropout': 0.1,
#    'epochs': 2.0,
#    'num_units': 32.0,
#    'optimizer': 'sgd'},
#   'generated': {'accuracy': 0.7947999835014343},
#   'utc_timestamp': 1687897790.563366,
#   'custom_metadata': {'event_file': 'wf_id_46010403-1191-4136-b072-ff84f6683856_11',
#    'log_path': 'tb_fc667c6d-d92a-48ec-afa4-2faf8c19b695/wf_id_46010403-1191-4136-b072-ff84f6683856_11'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'campaign_id': 'super_campaign',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'login_name',
#   'hostname': 'mac132633.ornl.gov',
#   'extra_metadata': {'place_holder': ''},
#   'debug': True,
#   'finished': True},
#  {'task_id': 'events.out.tfevents.1687883386.MAC132633.54853.37.v2',
#   'workflow_id': '46010403-1191-4136-b072-ff84f6683856',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 32.0,
#    'dropout': 0.2,
#    'epochs': 2.0,
#    'num_units': 32.0,
#    'optimizer': 'adam'},
#   'generated': {'accuracy': 0.8330000042915344},
#   'utc_timestamp': 1687897790.573195,
#   'custom_metadata': {'event_file': 'wf_id_46010403-1191-4136-b072-ff84f6683856_12',
#    'log_path': 'tb_fc667c6d-d92a-48ec-afa4-2faf8c19b695/wf_id_46010403-1191-4136-b072-ff84f6683856_12'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'campaign_id': 'super_campaign',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'login_name',
#   'hostname': 'mac132633.ornl.gov',
#   'extra_metadata': {'place_holder': ''},
#   'debug': True,
#   'finished': True},
#  {'task_id': 'events.out.tfevents.1687883389.MAC132633.54853.40.v2',
#   'workflow_id': '46010403-1191-4136-b072-ff84f6683856',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 64.0,
#    'dropout': 0.2,
#    'epochs': 2.0,
#    'num_units': 32.0,
#    'optimizer': 'adam'},
#   'generated': {'accuracy': 0.8438000082969666},
#   'utc_timestamp': 1687897795.774276,
#   'custom_metadata': {'event_file': 'wf_id_46010403-1191-4136-b072-ff84f6683856_13',
#    'log_path': 'tb_fc667c6d-d92a-48ec-afa4-2faf8c19b695/wf_id_46010403-1191-4136-b072-ff84f6683856_13'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'campaign_id': 'super_campaign',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'login_name',
#   'hostname': 'mac132633.ornl.gov',
#   'extra_metadata': {'place_holder': ''},
#   'debug': True,
#   'finished': True},
#  {'task_id': 'events.out.tfevents.1687883390.MAC132633.54853.43.v2',
#   'workflow_id': '46010403-1191-4136-b072-ff84f6683856',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 32.0,
#    'dropout': 0.2,
#    'epochs': 2.0,
#    'num_units': 32.0,
#    'optimizer': 'sgd'},
#   'generated': {'accuracy': 0.8011000156402588},
#   'utc_timestamp': 1687897795.780182,
#   'custom_metadata': {'event_file': 'wf_id_46010403-1191-4136-b072-ff84f6683856_14',
#    'log_path': 'tb_fc667c6d-d92a-48ec-afa4-2faf8c19b695/wf_id_46010403-1191-4136-b072-ff84f6683856_14'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'campaign_id': 'super_campaign',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'login_name',
#   'hostname': 'mac132633.ornl.gov',
#   'extra_metadata': {'place_holder': ''},
#   'debug': True,
#   'finished': True},
#  {'task_id': 'events.out.tfevents.1687883393.MAC132633.54853.46.v2',
#   'workflow_id': '46010403-1191-4136-b072-ff84f6683856',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 64.0,
#    'dropout': 0.2,
#    'epochs': 2.0,
#    'num_units': 32.0,
#    'optimizer': 'sgd'},
#   'generated': {'accuracy': 0.7872999906539917},
#   'utc_timestamp': 1687897795.785506,
#   'custom_metadata': {'event_file': 'wf_id_46010403-1191-4136-b072-ff84f6683856_15',
#    'log_path': 'tb_fc667c6d-d92a-48ec-afa4-2faf8c19b695/wf_id_46010403-1191-4136-b072-ff84f6683856_15'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'campaign_id': 'super_campaign',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'login_name',
#   'hostname': 'mac132633.ornl.gov',
#   'extra_metadata': {'place_holder': ''},
#   'debug': True,
#   'finished': True}]
