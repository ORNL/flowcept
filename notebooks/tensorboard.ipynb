# %%
# Sleeps are used because these notebooks are being tested automatically as part of the CI/CD. 
# In a normal user interaction, these sleeps would not be necessary.
from time import sleep

import os
import shutil
from uuid import uuid4
from time import sleep

# %%
def run_tensorboard_hparam_tuning(tensorboard_events_dir):
    # Code based on: https://www.tensorflow.org/tensorboard/hyperparameter_tuning_with_hparams
    wf_id = str(uuid4())
    import tensorflow as tf
    from tensorboard.plugins.hparams import api as hp

    fashion_mnist = tf.keras.datasets.fashion_mnist

    (x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
    x_train, x_test = x_train / 255.0, x_test / 255.0

    HP_NUM_UNITS = hp.HParam("num_units", hp.Discrete([16, 32]))
    HP_DROPOUT = hp.HParam("dropout", hp.RealInterval(0.1, 0.2))
    HP_OPTIMIZER = hp.HParam("optimizer", hp.Discrete(["adam", "sgd"]))
    HP_BATCHSIZES = hp.HParam("batch_size", hp.Discrete([32, 64]))

    HP_MODEL_CONFIG = hp.HParam("model_config")
    HP_OPTIMIZER_CONFIG = hp.HParam("optimizer_config")

    METRIC_ACCURACY = "accuracy"

    with tf.summary.create_file_writer(tensorboard_events_dir).as_default():
        hp.hparams_config(
            hparams=[
                HP_NUM_UNITS,
                HP_DROPOUT,
                HP_OPTIMIZER,
                HP_BATCHSIZES,
                HP_MODEL_CONFIG,
                HP_OPTIMIZER_CONFIG,
            ],
            metrics=[hp.Metric(METRIC_ACCURACY, display_name="Accuracy")],
        )

    def train_test_model(hparams, tensorboard_events_dir):
        model = tf.keras.models.Sequential(
            [
                tf.keras.layers.Flatten(),
                tf.keras.layers.Dense(
                    hparams[HP_NUM_UNITS], activation=tf.nn.relu
                ),
                tf.keras.layers.Dropout(hparams[HP_DROPOUT]),
                tf.keras.layers.Dense(10, activation=tf.nn.softmax),
            ]
        )
        model.compile(
            optimizer=hparams[HP_OPTIMIZER],
            loss="sparse_categorical_crossentropy",
            metrics=["accuracy"],
        )

        model.fit(
            x_train,
            y_train,
            epochs=1,
            callbacks=[
                tf.keras.callbacks.TensorBoard(tensorboard_events_dir),
                # log metrics
                hp.KerasCallback(tensorboard_events_dir, hparams),  # log hparams
            ],
            batch_size=hparams[HP_BATCHSIZES],
        )  # Run with 1 epoch to speed things up for tests
        _, accuracy = model.evaluate(x_test, y_test)
        return accuracy

    def run(run_dir, hparams):
        with tf.summary.create_file_writer(run_dir).as_default():
            hp.hparams(hparams)  # record the values used in this trial
            accuracy = train_test_model(hparams, tensorboard_events_dir)
            tf.summary.scalar(METRIC_ACCURACY, accuracy, step=1)

    session_num = 0

    for num_units in HP_NUM_UNITS.domain.values:
        for dropout_rate in (
            HP_DROPOUT.domain.min_value,
            HP_DROPOUT.domain.max_value,
        ):
            for optimizer in HP_OPTIMIZER.domain.values:
                for batch_size in HP_BATCHSIZES.domain.values:
                    # These two added ids below are optional and useful
                    # just to contextualize this run.
                    hparams = {
                        "workflow_id": wf_id,
                        "activity_id": "hyperparam_evaluation",
                        HP_NUM_UNITS: num_units,
                        HP_DROPOUT: dropout_rate,
                        HP_OPTIMIZER: optimizer,
                        HP_BATCHSIZES: batch_size,
                    }
                    run_name = f"wf_id_{wf_id}_{session_num}"
                    print("--- Starting trial: %s" % run_name)
                    print(f"{hparams}")
                    run(f"{tensorboard_events_dir}/" + run_name, hparams)
                    session_num += 1

    return wf_id

# %%
# Set log levels
os.environ['LOG_STREAM_LEVEL'] = "error"
os.environ['LOG_FILE_LEVEL'] = "debug"

# %% [markdown]
# ## Set up tensorboard events directory

# %%
# Optional: Delete old tensorboard directories
for file in os.listdir("."):
    if file.startswith("tb_"):
        shutil.rmtree(file)

# %%
tensorboard_events_dir = f"tb_{uuid4()}"
print(f"Creating new directory: {tensorboard_events_dir} ...")
os.mkdir(tensorboard_events_dir)
sleep(5)
print(f"Created.")
# Out:
# Creating new directory: tb_c3066ae2-33a2-4263-b61e-2f2986bf3a
workflow_id': '3377b78b-abe3-4e6f-8a95-014b8a381a26', 'activity_id': 'hyperparam_evaluation', HParam(name='num_units', domain=Discrete([16, 32]), display_name=None, description=None): 32, HParam(name='dropout', domain=RealInterval(0.1, 0.2), display_name=None, description=None): 0.2, HParam(name='optimizer', domain=Discrete(['adam', 'sgd']), display_name=None, description=None): 'sgd', HParam(name='batch_size', domain=Discrete([32, 64]), display_name=None, description=None): 64}
# 938/938 [==============================] - 1s 558us/step - loss: 1.1366 - accuracy: 0.6120
# 313/313 [==============================] - 0s 413us/step - loss: 0.7361 - accuracy: 0.7485

# %%
sleep(10)

# %% [markdown]
# ## Get the training metadata stored from this workflow

# %%
from flowcept import TaskQueryAPI
query_api = TaskQueryAPI()

# %%
_filter = {
    "workflow_id": workflow_id
}
docs = query_api.query(filter=_filter)
docs
# Out:
# [{'task_id': 'events.out.tfevents.1676046459.MAC132633.66236.1.v2',
#   'workflow_id': '3377b78b-abe3-4e6f-8a95-014b8a381a26',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 32.0,
#    'dropout': 0.1,
#    'num_units': 16.0,
#    'optimizer': 'adam'},
#   'generated': {'accuracy': 0.8203999996185303},
#   'utc_timestamp': 1676064464.598542,
#   'status': 'FINISHED',
#   'custom_metadata': {'event_file': 'wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_0',
#    'log_path': 'tb_c3066ae2-33a2-4263-b61e-2f2986bf3a71/wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_0'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'experiment_id': 'super-experiment',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'rsr',
#   'public_ip': '2620:0:2b30:e0::4b9',
#   'private_ip': '10.158.26.233',
#   'debug': True},
#  {'task_id': 'events.out.tfevents.1676046461.MAC132633.66236.4.v2',
#   'workflow_id': '3377b78b-abe3-4e6f-8a95-014b8a381a26',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 64.0,
#    'dropout': 0.1,
#    'num_units': 16.0,
#    'optimizer': 'adam'},
#   'generated': {'accuracy': 0.8147000074386597},
#   'utc_timestamp': 1676064464.710615,
#   'status': 'FINISHED',
#   'custom_metadata': {'event_file': 'wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_1',
#    'log_path': 'tb_c3066ae2-33a2-4263-b61e-2f2986bf3a71/wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_1'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'experiment_id': 'super-experiment',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'rsr',
#   'public_ip': '2620:0:2b30:e0::4b9',
#   'private_ip': '10.158.26.233',
#   'debug': True},
#  {'task_id': 'events.out.tfevents.1676046462.MAC132633.66236.7.v2',
#   'workflow_id': '3377b78b-abe3-4e6f-8a95-014b8a381a26',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 32.0,
#    'dropout': 0.1,
#    'num_units': 16.0,
#    'optimizer': 'sgd'},
#   'generated': {'accuracy': 0.7544999718666077},
#   'utc_timestamp': 1676064464.716521,
#   'status': 'FINISHED',
#   'custom_metadata': {'event_file': 'wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_2',
#    'log_path': 'tb_c3066ae2-33a2-4263-b61e-2f2986bf3a71/wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_2'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'experiment_id': 'super-experiment',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'rsr',
#   'public_ip': '2620:0:2b30:e0::4b9',
#   'private_ip': '10.158.26.233',
#   'debug': True},
#  {'task_id': 'events.out.tfevents.1676046463.MAC132633.66236.10.v2',
#   'workflow_id': '3377b78b-abe3-4e6f-8a95-014b8a381a26',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 64.0,
#    'dropout': 0.1,
#    'num_units': 16.0,
#    'optimizer': 'sgd'},
#   'generated': {'accuracy': 0.7480999827384949},
#   'utc_timestamp': 1676064464.724751,
#   'status': 'FINISHED',
#   'custom_metadata': {'event_file': 'wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_3',
#    'log_path': 'tb_c3066ae2-33a2-4263-b61e-2f2986bf3a71/wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_3'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'experiment_id': 'super-experiment',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'rsr',
#   'public_ip': '2620:0:2b30:e0::4b9',
#   'private_ip': '10.158.26.233',
#   'debug': True},
#  {'task_id': 'events.out.tfevents.1676046464.MAC132633.66236.13.v2',
#   'workflow_id': '3377b78b-abe3-4e6f-8a95-014b8a381a26',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 32.0,
#    'dropout': 0.2,
#    'num_units': 16.0,
#    'optimizer': 'adam'},
#   'generated': {'accuracy': 0.8230999708175659},
#   'utc_timestamp': 1676064469.839171,
#   'status': 'FINISHED',
#   'custom_metadata': {'event_file': 'wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_4',
#    'log_path': 'tb_c3066ae2-33a2-4263-b61e-2f2986bf3a71/wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_4'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'experiment_id': 'super-experiment',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'rsr',
#   'public_ip': '2620:0:2b30:e0::4b9',
#   'private_ip': '10.158.26.233',
#   'debug': True},
#  {'task_id': 'events.out.tfevents.1676046465.MAC132633.66236.16.v2',
#   'workflow_id': '3377b78b-abe3-4e6f-8a95-014b8a381a26',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 64.0,
#    'dropout': 0.2,
#    'num_units': 16.0,
#    'optimizer': 'adam'},
#   'generated': {'accuracy': 0.807699978351593},
#   'utc_timestamp': 1676064469.846393,
#   'status': 'FINISHED',
#   'custom_metadata': {'event_file': 'wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_5',
#    'log_path': 'tb_c3066ae2-33a2-4263-b61e-2f2986bf3a71/wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_5'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'experiment_id': 'super-experiment',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'rsr',
#   'public_ip': '2620:0:2b30:e0::4b9',
#   'private_ip': '10.158.26.233',
#   'debug': True},
#  {'task_id': 'events.out.tfevents.1676046466.MAC132633.66236.19.v2',
#   'workflow_id': '3377b78b-abe3-4e6f-8a95-014b8a381a26',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 32.0,
#    'dropout': 0.2,
#    'num_units': 16.0,
#    'optimizer': 'sgd'},
#   'generated': {'accuracy': 0.7681999802589417},
#   'utc_timestamp': 1676064469.853247,
#   'status': 'FINISHED',
#   'custom_metadata': {'event_file': 'wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_6',
#    'log_path': 'tb_c3066ae2-33a2-4263-b61e-2f2986bf3a71/wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_6'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'experiment_id': 'super-experiment',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'rsr',
#   'public_ip': '2620:0:2b30:e0::4b9',
#   'private_ip': '10.158.26.233',
#   'debug': True},
#  {'task_id': 'events.out.tfevents.1676046467.MAC132633.66236.22.v2',
#   'workflow_id': '3377b78b-abe3-4e6f-8a95-014b8a381a26',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 64.0,
#    'dropout': 0.2,
#    'num_units': 16.0,
#    'optimizer': 'sgd'},
#   'generated': {'accuracy': 0.7235999703407288},
#   'utc_timestamp': 1676064469.859638,
#   'status': 'FINISHED',
#   'custom_metadata': {'event_file': 'wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_7',
#    'log_path': 'tb_c3066ae2-33a2-4263-b61e-2f2986bf3a71/wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_7'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'experiment_id': 'super-experiment',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'rsr',
#   'public_ip': '2620:0:2b30:e0::4b9',
#   'private_ip': '10.158.26.233',
#   'debug': True},
#  {'task_id': 'events.out.tfevents.1676046471.MAC132633.66236.31.v2',
#   'workflow_id': '3377b78b-abe3-4e6f-8a95-014b8a381a26',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 32.0,
#    'dropout': 0.1,
#    'num_units': 32.0,
#    'optimizer': 'sgd'},
#   'generated': {'accuracy': 0.7878999710083008},
#   'utc_timestamp': 1676064474.980481,
#   'status': 'FINISHED',
#   'custom_metadata': {'event_file': 'wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_10',
#    'log_path': 'tb_c3066ae2-33a2-4263-b61e-2f2986bf3a71/wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_10'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'experiment_id': 'super-experiment',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'rsr',
#   'public_ip': '2620:0:2b30:e0::4b9',
#   'private_ip': '10.158.26.233',
#   'debug': True},
#  {'task_id': 'events.out.tfevents.1676046472.MAC132633.66236.34.v2',
#   'workflow_id': '3377b78b-abe3-4e6f-8a95-014b8a381a26',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 64.0,
#    'dropout': 0.1,
#    'num_units': 32.0,
#    'optimizer': 'sgd'},
#   'generated': {'accuracy': 0.7594000101089478},
#   'utc_timestamp': 1676064474.991858,
#   'status': 'FINISHED',
#   'custom_metadata': {'event_file': 'wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_11',
#    'log_path': 'tb_c3066ae2-33a2-4263-b61e-2f2986bf3a71/wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_11'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'experiment_id': 'super-experiment',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'rsr',
#   'public_ip': '2620:0:2b30:e0::4b9',
#   'private_ip': '10.158.26.233',
#   'debug': True},
#  {'task_id': 'events.out.tfevents.1676046468.MAC132633.66236.25.v2',
#   'workflow_id': '3377b78b-abe3-4e6f-8a95-014b8a381a26',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 32.0,
#    'dropout': 0.1,
#    'num_units': 32.0,
#    'optimizer': 'adam'},
#   'generated': {'accuracy': 0.8367000222206116},
#   'utc_timestamp': 1676064475.009682,
#   'status': 'FINISHED',
#   'custom_metadata': {'event_file': 'wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_8',
#    'log_path': 'tb_c3066ae2-33a2-4263-b61e-2f2986bf3a71/wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_8'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'experiment_id': 'super-experiment',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'rsr',
#   'public_ip': '2620:0:2b30:e0::4b9',
#   'private_ip': '10.158.26.233',
#   'debug': True},
#  {'task_id': 'events.out.tfevents.1676046470.MAC132633.66236.28.v2',
#   'workflow_id': '3377b78b-abe3-4e6f-8a95-014b8a381a26',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 64.0,
#    'dropout': 0.1,
#    'num_units': 32.0,
#    'optimizer': 'adam'},
#   'generated': {'accuracy': 0.8281000256538391},
#   'utc_timestamp': 1676064475.015598,
#   'status': 'FINISHED',
#   'custom_metadata': {'event_file': 'wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_9',
#    'log_path': 'tb_c3066ae2-33a2-4263-b61e-2f2986bf3a71/wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_9'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'experiment_id': 'super-experiment',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'rsr',
#   'public_ip': '2620:0:2b30:e0::4b9',
#   'private_ip': '10.158.26.233',
#   'debug': True},
#  {'task_id': 'events.out.tfevents.1676046474.MAC132633.66236.37.v2',
#   'workflow_id': '3377b78b-abe3-4e6f-8a95-014b8a381a26',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 32.0,
#    'dropout': 0.2,
#    'num_units': 32.0,
#    'optimizer': 'adam'},
#   'generated': {'accuracy': 0.835099995136261},
#   'utc_timestamp': 1676064480.183249,
#   'status': 'FINISHED',
#   'custom_metadata': {'event_file': 'wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_12',
#    'log_path': 'tb_c3066ae2-33a2-4263-b61e-2f2986bf3a71/wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_12'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'experiment_id': 'super-experiment',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'rsr',
#   'public_ip': '2620:0:2b30:e0::4b9',
#   'private_ip': '10.158.26.233',
#   'debug': True},
#  {'task_id': 'events.out.tfevents.1676046475.MAC132633.66236.40.v2',
#   'workflow_id': '3377b78b-abe3-4e6f-8a95-014b8a381a26',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 64.0,
#    'dropout': 0.2,
#    'num_units': 32.0,
#    'optimizer': 'adam'},
#   'generated': {'accuracy': 0.8220000267028809},
#   'utc_timestamp': 1676064480.190166,
#   'status': 'FINISHED',
#   'custom_metadata': {'event_file': 'wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_13',
#    'log_path': 'tb_c3066ae2-33a2-4263-b61e-2f2986bf3a71/wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_13'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'experiment_id': 'super-experiment',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'rsr',
#   'public_ip': '2620:0:2b30:e0::4b9',
#   'private_ip': '10.158.26.233',
#   'debug': True},
#  {'task_id': 'events.out.tfevents.1676046476.MAC132633.66236.43.v2',
#   'workflow_id': '3377b78b-abe3-4e6f-8a95-014b8a381a26',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 32.0,
#    'dropout': 0.2,
#    'num_units': 32.0,
#    'optimizer': 'sgd'},
#   'generated': {'accuracy': 0.7886000275611877},
#   'utc_timestamp': 1676064480.19707,
#   'status': 'FINISHED',
#   'custom_metadata': {'event_file': 'wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_14',
#    'log_path': 'tb_c3066ae2-33a2-4263-b61e-2f2986bf3a71/wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_14'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'experiment_id': 'super-experiment',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'rsr',
#   'public_ip': '2620:0:2b30:e0::4b9',
#   'private_ip': '10.158.26.233',
#   'debug': True},
#  {'task_id': 'events.out.tfevents.1676046478.MAC132633.66236.46.v2',
#   'workflow_id': '3377b78b-abe3-4e6f-8a95-014b8a381a26',
#   'activity_id': 'hyperparam_evaluation',
#   'used': {'batch_size': 64.0,
#    'dropout': 0.2,
#    'num_units': 32.0,
#    'optimizer': 'sgd'},
#   'generated': {'accuracy': 0.7484999895095825},
#   'utc_timestamp': 1676064480.203127,
#   'status': 'FINISHED',
#   'custom_metadata': {'event_file': 'wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_15',
#    'log_path': 'tb_c3066ae2-33a2-4263-b61e-2f2986bf3a71/wf_id_3377b78b-abe3-4e6f-8a95-014b8a381a26_15'},
#   'plugin_id': 'tensorboard',
#   'user': 'root',
#   'experiment_id': 'super-experiment',
#   'sys_name': 'Darwin',
#   'node_name': 'MAC132633',
#   'login_name': 'rsr',
#   'public_ip': '2620:0:2b30:e0::4b9',
#   'private_ip': '10.158.26.233',
#   'debug': True}]

# %%
consumer.stop()
