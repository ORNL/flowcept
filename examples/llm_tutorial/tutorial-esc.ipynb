# %%
import pandas as pd
import json
import copy, yaml
import matplotlib.pyplot as plt

from flowcept import Flowcept

# %%
docs = Flowcept.read_buffer_file(return_df=False, normalize_df=False)

# %%
len(docs)
# Out:
# 14

# %%
parent_forwards = []
for d in docs:
    if "subtype" in d and d["subtype"] == "parent_forward":
        parent_forwards.append(d)

# %%
parent_forwards
# Out:
# [{'task_id': '1757955539.185333',
#   'workflow_id': '6916a4d1-da1d-482b-8199-19e9449cedb8',
#   'activity_id': 'TransformerModel',
#   'started_at': 1757955539.185333,
#   'used': {'tensor': {'id': 4738865888,
#     'is_sparse': False,
#     'shape': [20, 20],
#     'device': 'cpu',
#     'nbytes': 3200,
#     'numel': 400,
#     'density': 0.94}},
#   'parent_task_id': '141585247680',
#   'custom_metadata': {'is_training': True},
#   'subtype': 'parent_forward',
#   'status': 'FINISHED',
#   'generated': {'tensor': {'id': 4796775024,
#     'is_sparse': False,
#     'shape': [20, 20, 254],
#     'device': 'cpu',
#     'nbytes': 406400,
#     'numel': 101600,
#     'density': 1.0}}},
#  {'task_id': '1757955539.252269',
#   'workflow_id': '6916a4d1-da1d-482b-8199-19e9449cedb8',
#   'activity_id': 'TransformerModel',
#   'started_at': 1757955539.252269,
#   'used': {'tensor': {'id': 4796820256,
#     'is_sparse': False,
#     'shape': [6, 20],
#     'device': 'cpu',
# ...

# %%
df = Flowcept.read_buffer_file(return_df=True, normalize_df=False)

# %%
df
# Out:
#                              workflow_id              name  \
# 0   f5276f07-311f-4bff-87d5-64b06da76610  DataPrepWorkflow
# 1   b3305e6f-3c11-4e66-be1a-a73d55435bbd               NaN
# 2   b3305e6f-3c11-4e66-be1a-a73d55435bbd               NaN
# 3   6916a4d1-da1d-482b-8199-19e9449cedb8               NaN
# 4   6916a4d1-da1d-482b-8199-19e9449cedb8               NaN
# 5   6916a4d1-da1d-482b-8199-19e9449cedb8               NaN
# 6   6916a4d1-da1d-482b-8199-19e9449cedb8               NaN
# 7   6916a4d1-da1d-482b-8199-19e9449cedb8               NaN
# 8   6916a4d1-da1d-482b-8199-19e9449cedb8               NaN
# 9   2d5d5a97-74a1-4dfc-b284-11bdd3c3d68a               NaN
# 10  2d5d5a97-74a1-4dfc-b284-11bdd3c3d68a               NaN
# 11  2d5d5a97-74a1-4dfc-b284-11bdd3c3d68a               NaN
# 12  2d5d5a97-74a1-4dfc-b284-11bdd3c3d68a               NaN
# 13  b3305e6f-3c11-4e66-be1a-a73d55435bbd    SearchWorkflow
#
#                                                  used  \
# ...
